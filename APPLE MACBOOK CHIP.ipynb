# %%
import requests
from bs4 import BeautifulSoup
import csv

# Define the URL of the product page and the number of pages to scrape
URL  = "https://www.amazon.in/Apple-MacBook-Chip-13-inch-256GB/product-reviews/B08N5T6CZ6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"

pages = 100


# Create a CSV file to store the data
with open('reviewset2.csv', 'w',encoding="utf-8", newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['review_title', 'review_text', 'review_rating'])
    
    # Scrape the reviews from each page
    for i in range(1, pages+1):
        # Send the HTTP request and parse the response
        res = requests.get( URL + '&pageNumber=' +str(i))
        soup = BeautifulSoup(res.text, 'html.parser')
        
        # Extract the review title, text, rating, and date
        review_titles = soup.find_all('a',{'data-hook':'review-title'})
        review_texts = soup.find_all('span',{'data-hook':'review-body'})
        review_ratings = soup.find_all('i',{'data-hook':'review-star-rating'})
        
        # Write the data to the CSV file
        for j in range(len(review_titles)):
            writer.writerow([review_titles[j].text, review_texts[j].text, review_ratings[j].text])

# %%
import pandas as pd

# %%
data =  pd.read_csv('reviewset2.csv')

# %%
data
# Out:
#                                           review_title  \
# 0    \nAwesome laptop miles ahead of windows counte...
# 1                                  \nAwesome Product\n
# 2                                            \nAbout\n
# 3                    \nBest laptop for everyday use.\n
# 4                                 \nIt's a MacBook!!\n
# ..                                                 ...
# 285                              \nBrilliant product\n
# 286  \nBest thing I bought this year.. thank you Am...
# 287                       \nUndoubtedly the best !!!\n
# 288                                \nSo far so good!\n
# 289                       \nIts great for developers\n
#
#                                            review_text       review_rating
# 0    \nSmooth like butterrrr , camera quality is no...  5.0 out of 5 stars
# 1    \ni was using macbook air early 2015 before. I...  5.0 out of 5 stars
# 2           \nChiz to jhkas hai lekin bahut khrcha h\n  5.0 out of 5 stars
# 3    \n1)Screen: great.2)Keyboard & Trackpad: good ...  5.0 out of 5 stars
# 4                                   \nIt's a MacBook\n  5.0 out of 5 stars
# ..                                                 ...                 ...
# 285           \nNeed a video on tips to fast install\n  5.0 out of 5 stars
# 286          \nEverything is great .. go for it guys\n  5.0 out of 5 stars
# 287  \nPremium product, fast & sleek… won’t have to...  5.0 out of 5 stars
# 288  \nA premium device for your premium needs. For...  5.0 out of 5 stars
# 289  \nIt’s great for development. Albeit it’s quit...  5.0 out of 5 stars
#
# [290 rows x 3 columns]
