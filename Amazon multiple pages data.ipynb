# %%
import requests
from bs4 import BeautifulSoup
import csv

# Define the URL of the product page and the number of pages to scrape
URL  = "https://www.amazon.in/Samsung-Galaxy-Cloud-Lavender-Storage/product-reviews/B08V9VMRQF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"

pages = 10


# Create a CSV file to store the data
with open('reviewset.csv', 'w',encoding="utf-8", newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['review_title', 'review_text', 'review_rating'])
    
    # Scrape the reviews from each page
    for i in range(1, pages+1):
        # Send the HTTP request and parse the response
        res = requests.get( URL + '&pageNumber=' +str(i))
        soup = BeautifulSoup(res.text, 'html.parser')
        
        # Extract the review title, text, rating, and date
        review_titles = soup.find_all('a',{'data-hook':'review-title'})
        review_texts = soup.find_all('span',{'data-hook':'review-body'})
        review_ratings = soup.find_all('i',{'data-hook':'review-star-rating'})
        
        # Write the data to the CSV file
        for j in range(len(review_titles)):
            writer.writerow([review_titles[j].text, review_texts[j].text, review_ratings[j].text])

# %%
import pandas as pd

# %%
data = pd.read_csv('reviewset.csv')

# %%
data
# Out:
#                                          review_title  \
# 0         \nEverything is great at this price range\n
# 1                                            \nGood\n
# 2                                      \nBest phone\n
# 3   \nOnly mobile, adaptor and usb port, nothing i...
# 4                \nBuy it for camera and Perfomance\n
# 5                       \nCamera quality is amazing\n
# 6              \nIt took too much time for charging\n
# 7                             \nBest overall mobile\n
# 8          \n'almost' FLAGSHIP and 'mostly' GOOD...\n
# 9                            \nBest phone under 40k\n
# 10                       \nBetter value price 31k/-\n
# 11                   \nOverall awesome phone at 25k\n
# 12  \nEverything is good, except the battery life ...
# 13                                 \nNew to Samsung\n
# 14                         \nStill Worth in 2023 !!\n
# 15                         \nShort and Crisp Review\n
# 16        \nAn all around package with a few flaws.\n
# 17                  \nBoon for Middle-class peoples\n
# 18                                              \n👍\n
# 19                             \nGood but not great\n
# 20  \nAwesome Flagship Features Under 30k  Review ...
# 21                                       \nCool set\n
# 22       \nA Good Phone with a not-so-good Battery!\n
# 23                            \nStill worth in 2022\n
# 24  \nPhone മൊത്തത്തിൽ തരക്കേടില്ല  ബാറ്ററി low ആണ...
# 25                           \nBest in class phone!\n
# 26                       \nGood Phone at the budget\n
# 27                               \nAmazing purchase\n
# 28                                        \nAverage\n
# 29      \nMost value for money at this price range.\n
# 30                                         \nMobile\n
# 31             \nDecent but 3 drawbacks u must know\n
# 32  \nPRO GRADE CAMERS IS NOTHING BUT FALSE ADVERT...
# 33                              \nBest in segment 👏\n
# 34                                \nValue for money\n
# 35                       \nOver all a decent choice\n
# 36                           \nBest Phone Under 40K\n
# 37  \nGood quality cam and screen.Battery drains o...
# 38                                      \nAwesome 😎\n
# 39                                   \nImpressive..\n
# 40       \nMRP OF THE PRODUCT IS ARTIFICIALLY HIKED\n
# 41        \nBest phone to buy in budget during sale\n
# 42      \nGreat buy below 30k, flagship exp partial\n
# 43                   \nPhone is perfect as expected\n
# 44      \nCamera and Performance is the top Notch❤️\n
# 45                                \nSo far no issue\n
# 46                                           \nCool\n
# 47                            \nGreat phone at 30 K\n
# 48                           \nBetter except gaming\n
# 49                     \nDecent phone for the price\n
#
#                                           review_text       review_rating
# 0   \nThe most I like is its dolby vision and dolb...  4.0 out of 5 stars
# 1                                            \nGood\n  4.0 out of 5 stars
# 2                        \nFingerprint slow reading\n  4.0 out of 5 stars
