# %%
import requests
from bs4 import BeautifulSoup
import csv

# Define the URL of the product page and the number of pages to scrape
URL  = "https://www.amazon.in/Samsung-Galaxy-Cloud-Lavender-Storage/product-reviews/B08V9VMRQF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"

pages = 100


# Create a CSV file to store the data
with open('reviewset1.csv', 'w',encoding="utf-8", newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['review_title', 'review_text', 'review_rating'])
    
    # Scrape the reviews from each page
    for i in range(1, pages+1):
        # Send the HTTP request and parse the response
        res = requests.get( URL + '&pageNumber=' +str(i))
        soup = BeautifulSoup(res.text, 'html.parser')
        
        # Extract the review title, text, rating, and date
        review_titles = soup.find_all('a',{'data-hook':'review-title'})
        review_texts = soup.find_all('span',{'data-hook':'review-body'})
        review_ratings = soup.find_all('i',{'data-hook':'review-star-rating'})
        
        # Write the data to the CSV file
        for j in range(len(review_titles)):
            writer.writerow([review_titles[j].text, review_texts[j].text, review_ratings[j].text])
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
import pandas as pd

# %%
data = pd.read_csv('reviewset1.csv')

# %%
data
# Out:
#                                           review_title  \
# 0    \nNot an extraordinary battery life hardly com...
# 1                        \nGood decision to buy this\n
# 2    \nMuch better options available in same range ...
# 3                                   \nI love Samsung\n
# 4                                        \nSupercool\n
# ..                                                 ...
# 725  \nMobile suddenly and silently stopped display...
# 726  \nCamera photo and vedio  clarity is good ,bat...
# 727                \nMVP in below ₹50k price bracket\n
# 728               \nSimply Awesome.... Just Loved it\n
# 729     \nIt is perfect mobile by battary is problem\n
#
#                                            review_text       review_rating
# 0    \nGood in this price range with this kind of O...  4.0 out of 5 stars
# 1                     \nSmooth experience as of now👍\n  4.0 out of 5 stars
# 2    \nCamera clarity not good, even six years old ...  4.0 out of 5 stars
# 3                                 \nVery nice mobile\n  4.0 out of 5 stars
# 4    \n1. Superfast.2. Fingerprint sensor is good.3...  4.0 out of 5 stars
# ..                                                 ...                 ...
# 725  \nI brought this mobile few days before Dusara...  2.0 out of 5 stars
# 726  \nBattery back up for normal usage is below av...  4.0 out of 5 stars
# 727  \nI purchased this phone after extensive resea...  5.0 out of 5 stars
# 728  \nThis is a really good phone.I bought it at 2...  5.0 out of 5 stars
# 729  \n\n\n\n\n                    The media could ...  5.0 out of 5 stars
#
# [730 rows x 3 columns]
