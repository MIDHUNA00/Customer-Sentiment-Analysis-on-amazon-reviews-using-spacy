# %%
import requests
from bs4 import BeautifulSoup
import csv

# Define the URL of the product page and the number of pages to scrape
URL = "https://www.amazon.in/Jixing-Strings-Acoustic-Guitars-Black/product-reviews/B00V5ZCVQA/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"
pages = 100


# Create a CSV file to store the data
with open('reviewset3.csv', 'w',encoding="utf-8", newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['review_title', 'review_text', 'review_rating'])
    
    # Scrape the reviews from each page
    for i in range(1, pages+1):
        # Send the HTTP request and parse the response
        res = requests.get( URL + '&pageNumber=' +str(i))
        soup = BeautifulSoup(res.text, 'html.parser')
        
        # Extract the review title, text, rating, and date
        review_titles = soup.find_all('a',{'data-hook':'review-title'})
        review_texts = soup.find_all('span',{'data-hook':'review-body'})
        review_ratings = soup.find_all('i',{'data-hook':'review-star-rating'})
        
        # Write the data to the CSV file
        for j in range(len(review_titles)):
            writer.writerow([review_titles[j].text, review_texts[j].text, review_ratings[j].text])
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
import pandas as pd

# %%
data = pd.read_csv('reviewset3.csv')

# %%
data
# Out:
#                                       review_title  \
# 0                                    \nNice Item\n
# 1                 \nSatisfied with the purchase.\n
# 2                           \nGood for showcase.\n
# 3                                           \nOk\n
# 4    \nIF YOU ARE A BEGINNER THEN JUST GO FOR IT\n
# ..                                             ...
# 815                                    \nDamaged\n
# 816                                 \nFive Stars\n
# 817                             \nawesome guitar\n
# 818                                 \nFive Stars\n
# 819                  \nBest guitar for beginners\n
#
#                                            review_text       review_rating
# 0    \nI don't know about guitars, and it's my firs...  4.0 out of 5 stars
# 1    \nwood: ok.action: nice and doesn't need much ...  4.0 out of 5 stars
# 2    \nIf you just got new passion but not sure if ...  3.0 out of 5 stars
# 3                                               \nOk\n  3.0 out of 5 stars
# 4    \nIf you are a beginner then just go it. It's ...  5.0 out of 5 stars
# ..                                                 ...                 ...
# 815                                        \nDamaged\n  1.0 out of 5 stars
# 816             \nAmazing product. Thanks to Amazon.\n  5.0 out of 5 stars
# 817         \nits is awesome.buy it.best for beginer\n  5.0 out of 5 stars
# 818                             \nVery good product.\n  5.0 out of 5 stars
# 819  \nNice product.  Good for beginners.  Loved it.\n  5.0 out of 5 stars
#
# [820 rows x 3 columns]
